# %%
#WARNING! Do not attempt to run this notebook if you are not on a modern computer.
#This code runs well over a hundred predictive models and
#We have removed for loops for the more intensive models to make them run
#only once rather than 40 times, but caution is still advised. Don't crash
#your poor laptop like we did (so many times)!

#Also note that we have included only the final versions of each of our models.
#Parameters were chosen after an intensive process that usually had to run
#overnight in order to test hundreds of possible combinations.

#We utilized methods discussed in class like looping over many parameter combinations
#and plotting results given in the "metrics" module of sklearn.

#Again, this took many hours, so it was not included here.

#Initializing
import pandas as pd
import numpy as np
import glob
import statsmodels.formula.api as sm
import scipy as sc
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from matplotlib.colors import ListedColormap
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics, svm
from sklearn.metrics import silhouette_samples, silhouette_score

# %matplotlib inline

# %%
#Reloading the data
cleanfiles=glob.glob('no_outliers/no_outliers*.csv') #use glob to make list of file names
data=[]
for filename in cleanfiles:
    data.append(pd.read_csv(filename))
print(data[0].head())
# Out:
#   class  redshift  redshift_err  green_mag  green_err  green_ext   red_mag  \
# 0   QSO  1.986327      0.000681   20.97149   0.033328   0.061561  21.05395
# 1   QSO  1.017390      0.000231   18.43328   0.007166   0.149876  18.06376
# 2   QSO  3.102721      0.000375   21.34668   0.047525   0.091967  21.08248
# 3   QSO  1.996235      0.000252   20.59937   0.026629   0.146573  20.74229
# 4   QSO  0.881320      0.000248   18.51914   0.007229   0.074286  18.48051
#
#     red_err   red_ext       velocity          Flux      distance
# 0  0.046748  0.042587  239339.149730  1.162150e-16   8529.206910
# 1  0.006917  0.103684  181527.923923  1.203777e-15   2650.126776
# 2  0.056927  0.063622  266168.962610  8.225951e-17  10137.868418
# 3  0.041663  0.101399  239698.298879  1.637232e-16   7185.957596
# 4  0.008202  0.051391  167706.775883  1.112249e-15   2757.011960

# %%
#Pandas can create dummies for us because they are awesome.

labelframe = [0]*40
mask = ['class']

for i in range(len(data)):
    try:
        dummy = pd.get_dummies(data[i], columns=mask)
        labelframe[i] = dummy
    except:
        continue

# %%
labelframe[0].dtypes
# Out:
# redshift        float64
# redshift_err    float64
# green_mag       float64
# green_err       float64
# green_ext       float64
# red_mag         float64
# red_err         float64
# red_ext         float64
# velocity        float64
# Flux            float64
# distance        float64
# class_GALAXY      uint8
# class_QSO         uint8
# dtype: object

# %%
#Running some calculations to get the variables we need for our clustering and our classifiers, and then 
#fixing some minor problems in the data
i=0
c=299792.458 #speed of light in km/s
H_o = 43.57285 #our experimental value from part 1
for i in range(len(labelframe)):
    M_Abs=[]
    Term2 = []
    m_apparent = []
    green = []
    red = []
    g_r = []
    for m in labelframe[i]["red_mag"]:
        m_apparent.append(m)
    for z in labelframe[i]['redshift']:
        #for our data, and for the purposes of these calculations, 
        #there shouldn't be any negative redshifts. Luckily, only a handful are below
        #zero in any dataframe in the collection. We decided to set them to 
        #zero if they were negative, but this caused errors in the calculations
        #that followed. We then decided that 1e-16 was "close enough" to zero for our purposes.
        if z<0:
            z=1e-16
        Term2.append(5*np.log((z*c)/H_o)+5) #Part of our calculation for Absolute Magnitude
    for a in range(len(m_apparent)):
        M_Abs.append(m_apparent[a] - Term2[a]) #2nd step of our calculation for Absolute Magnitude
    for j in range(len(M_Abs)):
        M_Abs[j] = M_Abs[j] - labelframe[i]["red_ext"][j] #3rd step of our calculation, subtracting off exctinction
    for g in labelframe[i]["green_mag"]:
        green.append(g) #"g" in "g-r"
    for r in labelframe[i]["red_mag"]:
        red.append(r) #"r" in "g-r"
    for rg in range(len(green)):
        g_r.append(green[rg]-red[rg]) #Finishing calculation for (g-r)
    labelframe[i]['M_Absolute']=M_Abs
    labelframe[i]["G_minus_R"]=g_r
    

labelframe[1].head()
# Out:
#    redshift  redshift_err  green_mag  green_err  green_ext   red_mag  \
# 0  1.820686      0.000526   20.61205   0.022871   0.037820  20.51275
# 1  2.496240      0.000466   20.82513   0.032272   0.100011  20.75636
# 2  0.986739      0.000188   17.63391   0.005398   0.116424  17.37311
# 3  0.538662      0.000106   18.75726   0.008411   0.086523  18.93735
# 4  2.915466      0.000461   19.85522   0.014668   0.209203  19.57490
#
#     red_err   red_ext       velocity          Flux     distance  class_GALAXY  \
# 0  0.030705  0.026164  232846.625777  1.618222e-16  7228.041711             0
# 1  0.041724  0.069187  254450.747147  1.329861e-16  7973.273290             0
# 2  0.005481  0.080542  178593.966898  2.513588e-15  1833.971786             0
# 3  0.011316  0.059856  121740.901234  8.932111e-16  3076.540596             0
# 4  0.014913  0.144726  263077.649221  3.249153e-16  5100.992090             0
#
#    class_QSO  M_Absolute  G_minus_R
# 0          1  -31.691538    0.09930
# 1          1  -33.068812    0.06877
# 2          1  -31.822741    0.26080
# 3          1  -27.211224   -0.18009
# 4          1  -35.102031    0.28032

# %%
labelframe[1].describe()
#We are still somehow getting some outliers, so let's get rid of 'em.
# Out:
#           redshift  redshift_err    green_mag    green_err    green_ext  \
# count  7116.000000   7116.000000  7116.000000  7116.000000  7116.000000
# mean      0.651765      0.010927    20.544832     0.087769     0.122540
# std       0.709390      0.653259     1.867810     0.113728     0.112702
# min      -0.000755     -1.000000    12.805840     0.001579     0.013911
# 25%       0.187352      0.000033    18.870700     0.012402     0.062219
# 50%       0.480674      0.000113    21.044300     0.049012     0.096074
# 75%       0.642627      0.000195    22.006465     0.126794     0.152772
# max       4.926229     54.040880    25.254490     1.750427     3.641495
#
#            red_mag      red_err      red_ext       velocity          Flux  \
# count  7116.000000  7116.000000  7116.000000    7116.000000  7.116000e+03
# mean     19.412855     0.038752     0.084773  111238.659786  8.933306e-16
# std       1.672467     0.037788     0.077967   69123.926149  4.433207e-15
# min      11.960700     0.001499     0.009623    -226.292692  2.249376e-18
# 25%      17.856675     0.009125     0.043043   50981.917594  4.479940e-17
# 50%      19.892695     0.028654     0.066463  111975.790566  1.086771e-16
# 75%      20.715853     0.056589     0.105687  137664.624845  8.045965e-16
# max      23.168030     0.680691     2.519169  283192.741516  2.145468e-13
#
#            distance  class_GALAXY    class_QSO   M_Absolute    G_minus_R
# count   7116.000000   7116.000000  7116.000000  7116.000000  7116.000000
# mean    1628.852624      0.801855     0.198145   -25.041155     1.131977
# std     3778.467169      0.398630     0.398630     6.026750     0.651396
# min        0.044388      0.000000     0.000000   -37.400894    -1.393750
# 25%        0.809768      1.000000     0.000000   -26.313984     0.604298
# 50%        2.719585      1.000000     0.000000   -25.350739     1.219330
# 75%        4.742358      1.000000     0.000000   -23.083534     1.680465
# max    61306.800288      1.000000     1.000000   156.344242     3.925640

# %%
#killing them outliers

for i in range(len(labelframe)):
    killer = labelframe[i][labelframe[i]["M_Absolute"]>-50]
    killer2 = killer[killer["M_Absolute"]<-1]
    killer3 = killer2[killer2["G_minus_R"]>-2]
    labelframe[i] = killer3

labelframe[1].describe()
# Out:
#           redshift  redshift_err    green_mag    green_err    green_ext  \
# count  7109.000000   7109.000000  7109.000000  7109.000000  7109.000000
# mean      0.652406      0.010938    20.544489     0.087771     0.121968
# std       0.709445      0.653581     1.868090     0.113751     0.104361
# min       0.001224     -1.000000    12.805840     0.001579     0.013911
# 25%       0.188637      0.000034    18.870610     0.012398     0.062220
# 50%       0.480879      0.000113    21.044010     0.048969     0.096074
# 75%       0.642955      0.000196    22.007380     0.126884     0.152719
# max       4.926229     54.040880    25.254490     1.750427     3.634993
#
#            red_mag      red_err      red_ext       velocity          Flux  \
# count  7109.000000  7109.000000  7109.000000    7109.000000  7.109000e+03
# mean     19.412117     0.038723     0.084377  111347.950568  8.937451e-16
# std       1.672223     0.037748     0.072196   69070.097201  4.435271e-15
# min      11.960700     0.001499     0.009623     366.706127  2.249376e-18
# 25%      17.856660     0.009118     0.043043   51296.790534  4.476165e-17
# 50%      19.892480     0.028650     0.066464  112011.606591  1.087062e-16
# 75%      20.715760     0.056582     0.105650  137711.880793  8.046632e-16
# max      23.168030     0.680691     2.514671  283192.741516  2.145468e-13
#
#            distance  class_GALAXY    class_QSO   M_Absolute    G_minus_R
# count   7109.000000   7109.000000  7109.000000  7109.000000  7109.000000
# mean    1630.454325      0.801660     0.198340   -25.155859     1.132371
# std     3779.982237      0.398778     0.398778     4.225572     0.651373
# min        0.044388      0.000000     0.000000   -37.400894    -1.393750
# 25%        0.809069      1.000000     0.000000   -26.315508     0.604660
# 50%        2.720117      1.000000     0.000000   -25.352709     1.220260
# 75%        4.751707      1.000000     0.000000   -23.095835     1.680690
# max    61306.800288      1.000000     1.000000    -2.487059     3.925640

# %%
sns.set_context('poster')
fig = plt.figure(figsize=(15, 8))
plt.scatter(labelframe[1]['G_minus_R'], labelframe[1]['M_Absolute'], c=labelframe[1]["class_GALAXY"],  marker="o", cmap='bwr')
fig.suptitle('Galaxy Color- Magnitude Diagram')
plt.xlabel('Luminosity')
plt.ylabel('Blue & Red')
plt.savefig('ScatterGalaxyColorMagDiagram.png')

# %% [markdown]
# #### Link to Wikipedia
# https://en.wikipedia.org/wiki/Galaxy_color%E2%80%93magnitude_diagram

# %% [markdown]
# ## K-Means Clustering

# %%
#We know there are 2 main clusters, "red" and "blue", and then"green" galaxies are inbetween
#so we will use 3 centers.
#Normally, you would test several different numbers of centers 
#and see which one performed the best using metrics, but since we already know
#that there are 3 groups (red, blue, green), we are going to go straight to 3 groups.

for i in range(len(labelframe)):
    X = labelframe[i][['M_Absolute','G_minus_R']]
    KMmodel = KMeans(n_clusters=3, n_init=100, init='random', max_iter=5)
    y_pred = KMmodel.fit_predict(X)
    labelframe[i]["K_Means_Cluster"] = y_pred
# Out:
# /Users/nicholaskeefer/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
fig = plt.figure(figsize=(15, 8))
plt.scatter(labelframe[39]["G_minus_R"], labelframe[39]['M_Absolute'], c=labelframe[39]["K_Means_Cluster"],  marker="o", cmap="jet")
fig.suptitle('K-Means of Galaxy Color-Mag Diagram')
plt.xlabel('Luminosity')
plt.ylabel('Blue & Red')
plt.savefig('KmeansGalaxyColorMagDiagram.png')

# %%
#Intra-cluster distance. This was looped as well.
print("Total intra-cluster distance:",-1*KMmodel.score(X))
# Out:
# Total intra-cluster distance: 42542.65583344477

# %% [markdown]
# ## DBSCAN Clustering

# %%
#DBSCAN Clustering. Note we originally used a 
#loop to do all 40, but it crashed everything hard.
#Here is the best example that we found.

X = labelframe[0][['M_Absolute','G_minus_R']]
db_model = DBSCAN(eps=1.5, min_samples=740)
db_model.fit(X)
y_pred = db_model.fit_predict(X)
labelframe[0]["DBSCAN_Cluster"] = y_pred

# %%
fig = plt.figure(figsize=(15, 8))
plt.scatter(labelframe[0]["G_minus_R"], labelframe[0]['M_Absolute'], c=labelframe[0]["DBSCAN_Cluster"],  marker="o", cmap="jet")
fig.suptitle('DBSCAN of Galaxy Color-Mag Diagram')
plt.xlabel('Luminosity')
plt.ylabel('Blue & Red')
plt.savefig('DBSCANGalaxyColorMagDiagram.png')

# %% [markdown]
# **Extremely sensitive to epsilon and min samples values.
# Especially min samples, which needs to be tested on each dataset of
# different sizes.
# K-means clustering is better for our data, since it all kind of "mashes together"
# into a blob, so hierarchical or DBSCAN clustering will perform poorly in comparison**.

# %%
labelframe[1].describe()
# Out:
#           redshift  redshift_err    green_mag    green_err    green_ext  \
# count  7109.000000   7109.000000  7109.000000  7109.000000  7109.000000
# mean      0.652406      0.010938    20.544489     0.087771     0.121968
# std       0.709445      0.653581     1.868090     0.113751     0.104361
# min       0.001224     -1.000000    12.805840     0.001579     0.013911
# 25%       0.188637      0.000034    18.870610     0.012398     0.062220
# 50%       0.480879      0.000113    21.044010     0.048969     0.096074
# 75%       0.642955      0.000196    22.007380     0.126884     0.152719
# max       4.926229     54.040880    25.254490     1.750427     3.634993
#
#            red_mag      red_err      red_ext       velocity          Flux  \
# count  7109.000000  7109.000000  7109.000000    7109.000000  7.109000e+03
# mean     19.412117     0.038723     0.084377  111347.950568  8.937451e-16
# std       1.672223     0.037748     0.072196   69070.097201  4.435271e-15
# min      11.960700     0.001499     0.009623     366.706127  2.249376e-18
# 25%      17.856660     0.009118     0.043043   51296.790534  4.476165e-17
# 50%      19.892480     0.028650     0.066464  112011.606591  1.087062e-16
# 75%      20.715760     0.056582     0.105650  137711.880793  8.046632e-16
# max      23.168030     0.680691     2.514671  283192.741516  2.145468e-13
#
#            distance  class_GALAXY    class_QSO   M_Absolute    G_minus_R  \
# count   7109.000000   7109.000000  7109.000000  7109.000000  7109.000000
# mean    1630.454325      0.801660     0.198340   -25.155859     1.132371
# std     3779.982237      0.398778     0.398778     4.225572     0.651373
# min        0.044388      0.000000     0.000000   -37.400894    -1.393750
# 25%        0.809069      1.000000     0.000000   -26.315508     0.604660
# 50%        2.720117      1.000000     0.000000   -25.352709     1.220260
# 75%        4.751707      1.000000     0.000000   -23.095835     1.680690
# max    61306.800288      1.000000     1.000000    -2.487059     3.925640
#
#        K_Means_Cluster
# count      7109.000000
# mean          0.596568
# std           0.818415
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           2.000000

# %% [markdown]
# ## SVM Classifier

# %%
#SVM Classifier
#VERY computationally expensive, so we only include one example here.

#Selecting relevant variables (part 1 scatter matrix)
X_train = labelframe[0][['redshift', 'green_mag', 'red_mag', 'M_Absolute']]
y_train = labelframe[0][['class_GALAXY']]
X_test = labelframe[4][['redshift', 'green_mag', 'red_mag', 'M_Absolute']]
y_test = labelframe[4][['class_GALAXY']]
#best kernel:rbf
#best C: 103
#consistent upon cross-validation
svm_model = svm.SVC(kernel='rbf', C=103)
svm_model.fit(X_train, y_train)

y_pred = svm_model.predict(X_test)


labelframe[4]['SVM_class'] = y_pred
# Out:
# /Users/nicholaskeefer/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/nicholaskeefer/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
#We looped over many of these accuracy scores and took a weighted average. 
#Overall result was 98.3% accuracy.
#Here's one really good example on set 40 (index 39):
metrics.accuracy_score(y_true = y_test, y_pred=y_pred)
# Out:
# 0.984094371036877

# %%
metrics.confusion_matrix(y_true=y_test, y_pred=y_pred)
# Out:
# array([[ 2618,   161],
#        [   60, 11499]], dtype=int64)

# %%
#plotting predictions made by SVM
fig = plt.figure(figsize=(15, 8))
plt.scatter(labelframe[4]["G_minus_R"], labelframe[4]['M_Absolute'], c=labelframe[4]["SVM_class"],  marker="o", cmap="jet")
fig.suptitle('SVM of Galaxy Color-Mag Diagram')
plt.xlabel('Luminosity')
plt.ylabel('Blue & Red')
plt.savefig('SVMGalaxyColorMagDiagram.png')

# %% [markdown]
# **The data is sort of "mixed together" near the middle of our data in the "green valley."
# Let's see if our classifier can overcome this.**

# %% [markdown]
# ## KNN Classifier

# %%
knn_model = KNeighborsClassifier(n_neighbors=20)
knn_model.fit(X_train, y_train)

knn_y_pred = knn_model.predict(X_test)
metrics.accuracy_score(y_true = y_test, y_pred=knn_y_pred)

labelframe[4]["KNN_class"] = knn_y_pred
# Out:
# /Users/nicholaskeefer/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
metrics.confusion_matrix(y_true = y_test, y_pred=knn_y_pred)
# Out:
# array([[ 5124,   388],
#        [  103, 22614]])

# %%
#Again, we looped this with appropriate weights. 
#Final result was 98.2% accuracy on the test data.
metrics.accuracy_score(y_true = y_test, y_pred=knn_y_pred)
# Out:
# 0.9826065393744022

# %%
#Plotting predictions made by knn
fig = plt.figure(figsize=(15, 8))
plt.scatter(labelframe[4]["G_minus_R"], labelframe[4]['M_Absolute'], c=labelframe[4]["KNN_class"],  marker="o", cmap="jet")
fig.suptitle('KNN of Galaxy Color-Mag Diagram')
plt.xlabel('Luminosity')
plt.ylabel('Blue & Red')
plt.savefig('KNNGalaxyColorMagDiagram.png')
